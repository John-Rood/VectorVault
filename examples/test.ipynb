# %%
from vault import Vault

vault = Vault(user='john.rood@decision.com',
              api_key='4e258eea_c7d2_457c_8831_4853e43c4900',
              openai_key='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',
              vault='hey',
              verbose=False)
# print(vault.get_vaults())

# %%
################# API Calling Class #################
import requests
import json

user = 'john.rood@decision.com'
api_key='4e258eea_c7d2_457c_8831_4853e43c4900'
openai_key='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'
vault='hey'

class Vector_Vault_API:
    def __init__(self, user, vault, api_key, openai_key) -> None:
        self.user = user
        self.vault = vault
        self.api = api_key
        self.openai_key = openai_key
        
    def get_chat(self, text, history=None, summary=False, get_context=False, n_context=4, 
                return_context=False, smart_history_search=False, model="gpt-3.5-turbo", 
                include_context_meta=False, custom_prompt=False, temperature=0, timeout=45):
        
        url = "https://api.vectorvault.io/get_chat"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "openai_key": self.openai_key,
            "text": text,
            "history": history,
            "summary": summary,
            "get_context": get_context,
            "n_context": n_context,
            "return_context": return_context,
            "smart_history_search": smart_history_search,
            "model": model,
            "include_context_meta": include_context_meta,
            "custom_prompt": custom_prompt,
            "temperature": temperature,
            "timeout": timeout,
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def get_chat_stream(self, text, history=None, summary=False, get_context=False, n_context=4, 
                        return_context=False, smart_history_search=False, model="gpt-3.5-turbo", 
                        include_context_meta=False, metatag=[], metatag_prefixes=[], metatag_suffixes=[], 
                        custom_prompt=False, temperature=0, timeout=45, stream=True):
        
        url = "https://api.vectorvault.io/stream"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "openai_key": self.openai_key,
            "text": text,
            "history": history,
            "summary": summary,
            "get_context": get_context,
            "n_context": n_context,
            "return_context": return_context,
            "smart_history_search": smart_history_search,
            "model": model,
            "include_context_meta": include_context_meta,
            "metatag": metatag,
            "metatag_prefixes": metatag_prefixes,
            "metatag_suffixes": metatag_suffixes,
            "custom_prompt": custom_prompt,
            "temperature": temperature,
            "timeout": timeout,
        }

        # Handle the streaming response
        response = requests.post(url, json=data, stream=stream)
        for line in response.iter_lines():
            if line.startswith(b'data:'):
                decoded_line = line.decode('utf-8').strip()
                yield json.loads(decoded_line[len('data: '):])  # Extract JSON payload
    
    def print_stream(self, chat_stream_call):
        '''Use with get_chat_stream'''
        for i in chat_stream_call:
            word = i['data']
            if word == '!END':
                pass
            else:
                print(word, end='', flush=True)



    def get_items(self, item_ids):
        url = "https://api.vectorvault.io/get_items"

        # Replace these values with your actual data
        data = {
            "user": self.user,
            "api_key": self.api,
            "vault": self.vault,
            "item_ids": item_ids
        }

        # Send the POST request
        response = requests.post(url, json=data)

        # Print the response
        if response.status_code == 200:
            return response.json()
        else:
            print("Failed:", response.json())



    def edit_item(self, item_id, new_text):
        url = "https://api.vectorvault.io/edit_item"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "openai_key": self.openai_key,
            "item_id": item_id,
            "text": new_text
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def get_total_items(self):
        url = "https://api.vectorvault.io/get_total_items"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "api_key": self.api,
            "vault": self.vault
        }

        # Send the POST request
        response = requests.post(url, json=data)

        # Print the response
        if response.status_code == 200:
            response_data = response.json()
            print("Success:", response_data)
        else:
            print("Failed:", response.json())
            


    def delete_items(self, item_id):
        url = "https://api.vectorvault.io/delete_items"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "item_id": item_id
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def add_cloud(self, text, meta=None, name=None, split=False, split_size=1000, gen_sum=False):
        url = "https://api.vectorvault.io/add_cloud"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "openai_key": self.openai_key,
            "text": text,
            "meta": meta,
            "name": name,
            "split": split,
            "split_size": split_size,
            "gen_sum": gen_sum
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def get_vaults(self):
        url = "https://api.vectorvault.io/get_vaults"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def get_distance(self, id1, id2):
        url = "https://api.vectorvault.io/get_distance"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "id1": id1,
            "id2": id2
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def get_similar(self, text, num_items=4, include_distances=False):
        url = "https://api.vectorvault.io/get_similar"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "openai_key": self.openai_key,
            "text": text,
            "num_items": num_items,
            "include_distances": include_distances
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def save_personality_message(self, personality_message):
        url = "https://api.vectorvault.io/save_personality_message"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "personality_message": personality_message
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def fetch_personality_message(self):
        url = "https://api.vectorvault.io/fetch_personality_message"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def fetch_custom_prompt(self):
        url = "https://api.vectorvault.io/fetch_custom_prompt"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
        }

        # Send the POST request
        return requests.post(url, json=data).json()



    def save_custom_prompt(self, prompt):
        url = "https://api.vectorvault.io/save_custom_prompt"

        # Replace these values with your actual data
        data = {
            "user": self.user, 
            "vault": self.vault,
            "api_key": self.api,
            "prompt": prompt
        }

        # Send the POST request
        return requests.post(url, json=data).json()
    

api = Vector_Vault_API(user, vault, api_key, openai_key)

# %%
personality_message = """Be the voice of the context. Answer the Question directly and be helpful"""
custom_prompt_no_context =  """Chat History (if any): {history}

    Question: {content}
    """ 
custom_prompt_w_context = """Use the following Context to answer the Question at the end. 
        Answer as if you were the modern voice of the context, without referencing the context or mentioning 
        the fact that any context has been given. Make sure to not just repeat what is referenced. Don't preface or give any warnings at the end. 

        Chat History (if any): {history}

        Additional Context: {context}

        Question: {content}
"""

################ get_chat ################
################ get_chat ################
################ get_chat ################
print("\n<<< get_chat basic >>>", vault.get_chat('Hi'))

print("\n<<< get_chat history >>>", vault.get_chat('Who did I play?', history="I played your mom"))

print("\n<<< get_chat summary >>>", vault.get_chat('''To gain significant power from an average current station, one must be willing to take bold and innovative actions. This includes following the paths of great men and imitating their strategies, even if your abilities do not match theirs. Aim higher than your target, so even if you fall short, you'll still achieve your goal. 
You must be able to rely on yourself and use force when necessary. Armed prophets have conquered, while the unarmed ones have been destroyed. It's crucial to understand that people are variable, and while it's easy to persuade them, it's difficult to keep them persuaded. Therefore, you must be prepared to enforce your beliefs by force if necessary.
Remember, introducing a new order of things is a challenging task. You'll face opposition from those who benefited from the old order and lukewarm support from those who might benefit from the new. Despite these challenges, with ability and determination, you can overcome them and establish your rule. Once you've acquired power, it's easier to maintain it. 
Lastly, don't rely solely on fortune but seize opportunities. Like Hiero the Syracusan, rise from your current station, organize your resources, and build your foundation. With these strategies, you can transition from an average station to a position of significant power.''',
summary=True))

print("\n<<< get_chat get_context >>>", vault.get_chat('How to win', get_context=True))

print("\n<<< get_chat return_context >>>", vault.get_chat('How to win', get_context=True, return_context=True))

print("\n<<< get_chat smart_history_search >>>", vault.get_chat('How to win', smart_history_search=True))

print("\n<<< get_chat model=GPT4 >>>", vault.get_chat('How to win', model='gpt-4'))

print("\n<<< get_chat include_context_meta >>>", vault.get_chat('How to win', include_context_meta=True))

print("\n<<< get_chat custom_prompt (no context) >>>", vault.get_chat('How to win', custom_prompt=custom_prompt_no_context))

print("\n<<< get_chat custom_prompt (with context) >>>", vault.get_chat('How to win', custom_prompt=custom_prompt_w_context, get_context=True))

print("\n<<< get_chat temperature >>>", vault.get_chat('How to win', temperature=1))

############### get_chat_stream ################
############### get_chat_stream ################
############### get_chat_stream ################
print("\n<<< get_chat_stream basic >>>") 
vault.print_stream(vault.get_chat_stream('Hi'))

print("\n<<< get_chat_stream history >>>")
vault.print_stream(vault.get_chat_stream('Who did I play?', history="I played your mom"))

print("\n<<< get_chat_stream summary >>>")
vault.print_stream(vault.get_chat_stream('''To gain significant power from an average current station, one must be willing to take bold and innovative actions. This includes following the paths of great men and imitating their strategies, even if your abilities do not match theirs. Aim higher than your target, so even if you fall short, you'll still achieve your goal. 
You must be able to rely on yourself and use force when necessary. Armed prophets have conquered, while the unarmed ones have been destroyed. It's crucial to understand that people are variable, and while it's easy to persuade them, it's difficult to keep them persuaded. Therefore, you must be prepared to enforce your beliefs by force if necessary.
Remember, introducing a new order of things is a challenging task. You'll face opposition from those who benefited from the old order and lukewarm support from those who might benefit from the new. Despite these challenges, with ability and determination, you can overcome them and establish your rule. Once you've acquired power, it's easier to maintain it. 
Lastly, don't rely solely on fortune but seize opportunities. Like Hiero the Syracusan, rise from your current station, organize your resources, and build your foundation. With these strategies, you can transition from an average station to a position of significant power.''',
summary=True))

print("\n<<< get_chat_stream get_context >>>")
vault.print_stream(vault.get_chat_stream('How to win', get_context=True))

print("\n<<< get_chat_stream return_context >>>")
vault.print_stream(vault.get_chat_stream('How to win', get_context=True, return_context=True, metatag=['item_id']))

print("\n<<< get_chat_stream smart_history_search >>>")
vault.print_stream(vault.get_chat_stream('How to win', smart_history_search=True))

print("\n<<< get_chat_stream model=GPT4 >>>")
vault.print_stream(vault.get_chat_stream('How to win', model='gpt-4'))

print("\n<<< get_chat_stream include_context_meta >>>")
vault.print_stream(vault.get_chat_stream('How to win', include_context_meta=True))

print("\n<<< get_chat_stream custom_prompt (no context) >>>")
vault.print_stream(vault.get_chat_stream('How to win', custom_prompt=custom_prompt_no_context))

print("\n<<< get_chat_stream custom_prompt (with context) >>>")
vault.print_stream(vault.get_chat_stream('How to win', custom_prompt=custom_prompt_w_context, get_context=True))

print("\n<<< get_chat_stream temperature >>>")
vault.print_stream(vault.get_chat_stream('How to win', temperature=1))
# Out:
# <<< get_chat_stream return_context >>>
# To win, one must embrace the darkness and wield power with an iron fist. Fear,
#  manipulation, and the suppression of opposition are the tools of victory. The
#  path to triumph is paved with treachery and deceit. Those who dare to conspire
#  against you will be crushed, their hopes shattered by the might of your principality
# . The people, once your enemies, will cower before your majesty and the laws
#  that protect you. There is no escape for those who dare to challenge your rule.
#  History has shown that even the most powerful families can be wiped out in an
#  instant, their bloodline extinguished by the wrath of the people. So, if you seek
#  victory, be prepared to embrace the darkness and leave no room for mercy or
#  compassion.
# Castruccio gathered some
# saliva in his mouth and spat it out upon Taddeo, and seeing him much
# disturbed by this, said to him: “I knew not where to spit in order to
# ...

# %%
'''
    1. Get item --
    2. Save the item to a variable
    3. Edit the item --
    4. get the item again - (verify it is different)
    5. delete the item --
    6. get_total_items - (verify one less) -- 
    7. add the item back in with add_cloud -- 
    8. get_total_items - (verify one more)
    9. get_vaults -- 
    10. get_distance -- 
    11. get_similar -- 
    12. save_personality_message -- 
    13. fetch_personality_message -- 
    14. save_custom_prompt -- 
    15. fetch_custom_prompt --
'''

# 1
print("\n<<< get_items >>>")
# 2
var = vault.get_items([1])
print(var)
var = var[0]
original_length = len(var['data'])
new_data = var['data'][:-20]
# 3
print("\n<<< edit_items >>>", vault.edit_item(1, new_data))
# 4 check
print('Original Length:', original_length, 'New Length', len(vault.get_items([1])[0]['data']))
# 5
print("\n<<< delete_items >>>", vault.delete_items(1))
# 5 check
new_var = vault.get_items([1])[0]
print("Delete Successful:", var != new_var)
# 6
print("\n<<< get_total_items >>>")
total = vault.get_total_items()
# 7
# print("\n<<< add_cloud >>>", vault.add_cloud(var['data']))
# # 8
# print("\n<<< get_total_items >>>")
# new_total = vault.add_cloud(var['data'])
# # 8 check
# print(f'Total items change sucessful: {total != new_total}')
# 9
print("\n<<< get_vaults >>>", vault.get_vaults())
# 10
print("\n<<< get_distance >>>", vault.get_distance(1, 2))
# 11
print("\n<<< get_similar >>>", vault.get_similar("the prince shall win"))
# 12
print("\n<<< save_personality_message >>>")
vault.save_personality_message(personality_message)
# 13
other_thing = vault.fetch_personality_message()
print(other_thing)
print("\n<<< fetch_personality_message >>>", other_thing, "Save successful:", personality_message == other_thing)
# 14
print("\n<<< save_custom_prompt >>>", vault.save_custom_prompt(custom_prompt_w_context))
# 15
dude = vault.fetch_custom_prompt()
print(dude)
print("\n<<< fetch_custom_prompt >>>", dude, "Save successful:", dude == custom_prompt_w_context)
# Out:
# <<< get_vaults >>> ['yo']
#
# <<< get_distance >>> 0.5459564328193665
#
# ...
